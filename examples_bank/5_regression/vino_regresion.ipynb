# %% [markdown]
# # Cargar el data set

# %%
from google.colab import files
files.upload()

# %%
import pandas as pd

vino=pd.read_csv('vino.csv') #con esto deberiamos de cargar el data sets

# %%
vino
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
vino.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
vino.tail()
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 1594                 32.0                  44.0  0.99490  3.45       0.58
# 1595                 39.0                  51.0  0.99512  3.52       0.76
# 1596                 29.0                  40.0  0.99574  3.42       0.75
# 1597                 32.0                  44.0  0.99547  3.57       0.71
# 1598                 18.0                  42.0  0.99549  3.39       0.66
#
#       alcohol  quality
# 1594     10.5        5
# ...

# %%
vino.rename(columns = {'fixed acidity':'acidez fija','volatile acidity':'acidez volátil',\
                       'citric acid':'ácido citrico',\
                       'residual sugar':'azucar residual','chlorides':'Cloruros',\
                       'free sulfur dioxide':'dioxido de azufre libre',\
                       'total sulfur dioxide':'dioxido de azufre total',\
                       'density':'densidad','pH':'pH',\
                       'sulphates':'sulfatos','alcohol':'alcohol','quality':'calidad'},\
            inplace = True)

# %%
vino.tail()
# Out:
#       acidez fija  acidez volátil  ácido citrico  azucar residual  Cloruros  \
# 1594          6.2           0.600           0.08              2.0     0.090
# 1595          5.9           0.550           0.10              2.2     0.062
# 1596          6.3           0.510           0.13              2.3     0.076
# 1597          5.9           0.645           0.12              2.0     0.075
# 1598          6.0           0.310           0.47              3.6     0.067
#
#       dioxido de azufre libre  dioxido de azufre total  densidad    pH  \
# 1594                     32.0                     44.0   0.99490  3.45
# 1595                     39.0                     51.0   0.99512  3.52
# 1596                     29.0                     40.0   0.99574  3.42
# 1597                     32.0                     44.0   0.99547  3.57
# 1598                     18.0                     42.0   0.99549  3.39
#
#       sulfatos  alcohol  calidad
# 1594      0.58     10.5        5
# ...

# %% [markdown]
# # Hay 12 atributos
# # Acidez fija , acidez volatil, acido citrico, azucar residual, cloruros, dioxido de azufre libre, dioxido de azufre total, densidad, pH, sulfatos, alcohol

# %%
#info del data sets para obtener 1,numero total de filas. 2,tipo de cada atributo. 3,numero de valores no nulos
vino.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   acidez fija              1599 non-null   float64
#  1   acidez volátil           1599 non-null   float64
#  2   ácido citrico            1599 non-null   float64
#  3   azucar residual          1599 non-null   float64
#  4   Cloruros                 1599 non-null   float64
#  5   dioxido de azufre libre  1599 non-null   float64
#  6   dioxido de azufre total  1599 non-null   float64
#  7   densidad                 1599 non-null   float64
#  8   pH                       1599 non-null   float64
#  9   sulfatos                 1599 non-null   float64
#  10  alcohol                  1599 non-null   float64
#  11  calidad                  1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# # Hay 1599 unstancias en el conjunto de datos
#
#
# *   pequeño
# *   todos los datos tienen la misma cantidad detos lo que significa que todos los datos estan completo
# *
# *   Todos los datos son flotantes exepto el de calidad, puede señalar que para dar una calidad al vino solo sea en numeros enteros

# %% [markdown]
# # HIstograma de la muestra
# PUede trazar este atributo a la vez, o puede llamar el metodo hist() en todo conjunto de datos (como se muestra en el siguiente ejemplo de codigo) y trazara un histograma para cada atributo numerico.)

# %%
import matplotlib.pyplot as plt

vino['acidez fija'].plot(kind='hist')

plt.show()

# %%
vino['acidez volátil'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
vino['ácido citrico'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
vino['azucar residual'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
vino['Cloruros'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
vino['dioxido de azufre libre'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
vino['dioxido de azufre total'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
vino['densidad'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
vino['pH'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
vino['sulfatos'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
vino['alcohol'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
vino['calidad'].plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
vino.hist(bins = 11, figsize=(20,15)) #bins numero de columnas a mostrar, 
plt.show()

# %%
#conjunto de entrenamiento y conjunto de testeo (creo que esto todavia no)
#visualizar los datos
vino.plot(kind = 'scatter', x = 'acidez fija', y = 'calidad', alpha = 1)
plt.show() #(duda, como hacer para entender mejor el comportamiento de la vino y calidad)

# %%
vino.keys()
# Out:
# Index(['acidez fija', 'acidez volátil', 'ácido citrico', 'azucar residual',
#        'Cloruros', 'dioxido de azufre libre', 'dioxido de azufre total',
#        'densidad', 'pH', 'sulfatos', 'alcohol', 'calidad'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt 
vino.plot(kind = 'scatter', y = 'calidad', x = 'acidez volátil', alpha = 1)
plt.show()

# %%
vino.plot(kind = 'scatter', x = 'alcohol', y = 'acidez volátil', alpha = 1)
plt.show()

# %% [markdown]
# #Preparar los datos para algoritmos de aprendizaje.
# Hacer separacion inicial de datos para entrenar y para testear

# %%
#conjunto de entrenamiento y de testeo, evaluar desempeno de testeo
#la funcion de divida_train
def divida_train_test(datos,tasa_testeo):
    import numpy as np
    indices_reordenados = np.random.permutation((len(datos)))
    tamaño_train = int(len(datos)*(1-tasa_testeo))
    train_set = datos.iloc[indices_reordenados[:tamaño_train]] #tamaño de los daots de entrenamiento
    test_set = datos.iloc[indices_reordenados[tamaño_train:]] #hasta el final de los datos
    return train_set, test_set

# %%
vino_train, vino_test = divida_train_test(vino, 0.2)

# %% [markdown]
# # Verificando la división en entrenamiento y testeo

# %%
len(vino_train)/len(vino)
# Out:
# 0.7998749218261413

# %%
len(vino_test)/len(vino) #comprobamos que esta en un 80%
# Out:
# 0.20012507817385866

# %%
vino_train
# Out:
#       acidez fija  acidez volátil  ácido citrico  azucar residual  Cloruros  \
# 40            7.3           0.450           0.36              5.9     0.074
# 396           6.6           0.735           0.02              7.9     0.122
# 1180          8.2           0.350           0.33              2.4     0.076
# 1330          7.4           0.600           0.26              2.1     0.083
# 909           7.3           0.305           0.39              1.2     0.059
# ...           ...             ...            ...              ...       ...
# 1105          6.3           0.570           0.28              2.1     0.048
# 33            6.9           0.605           0.12             10.7     0.073
# 1521          6.9           0.480           0.20              1.9     0.082
# 1534          6.6           0.560           0.14              2.4     0.064
# 69            8.0           0.705           0.05              1.9     0.074
#
# ...

# %%
len(vino_train)+ len(vino_test)
# Out:
# 1599

# %%
divida_train_test(vino,0.2)
# Out:
# (      acidez fija  acidez volátil  ácido citrico  azucar residual  Cloruros  \
#  1099          8.6            0.52           0.38              1.5     0.096
#  1391          8.0            0.64           0.22              2.4     0.094
#  1544          8.4            0.37           0.43              2.3     0.063
#  1404          8.0            0.50           0.39              2.6     0.082
#  1085          6.8            0.48           0.08              1.8     0.074
#  ...           ...             ...            ...              ...       ...
#  134           7.9            1.04           0.05              2.2     0.084
#  395          12.0            0.37           0.76              4.2     0.066
#  1084          7.2            0.38           0.30              1.8     0.073
#  127           8.1            1.33           0.00              1.8     0.082
#  780           7.0            0.57           0.00              2.0     0.190
#
# ...

# %%
from sklearn.model_selection import train_test_split

vino_train, vino_test = train_test_split(vino, test_size = 0.2, random_state = 42) 
#vamos bien, vamos bien

# %% [markdown]
# # limpar los datos y llenar datos faltantes, No hace falta ya esta mas que limpio

# %% [markdown]
# #Explorar correlaciones lineales con la variable objetivo

# %% [markdown]
# ![68747470733a2f2f6769746875622e636f6d2f6d6172636f2d63616e61732f746163612f626c6f622f6d61696e2f7265662f6765726f6e2f706172745f312f636861705f322f345f76697375616c697a652f6669677572615f325f31345.png](data:image/png;base64,...)

# %%
vino.corr().calidad.sort_values(ascending = False) #duda
# Out:
# calidad                    1.000000
# alcohol                    0.476166
# sulfatos                   0.251397
# ácido citrico              0.226373
# acidez fija                0.124052
# azucar residual            0.013732
# dioxido de azufre libre   -0.050656
# pH                        -0.057731
# Cloruros                  -0.128907
# densidad                  -0.174919
# dioxido de azufre total   -0.185100
# acidez volátil            -0.390558
# Name: calidad, dtype: float64

# %%
vino.corr()
# Out:
#                          acidez fija  acidez volátil  ácido citrico  \
# acidez fija                 1.000000       -0.256131       0.671703
# acidez volátil             -0.256131        1.000000      -0.552496
# ácido citrico               0.671703       -0.552496       1.000000
# azucar residual             0.114777        0.001918       0.143577
# Cloruros                    0.093705        0.061298       0.203823
# dioxido de azufre libre    -0.153794       -0.010504      -0.060978
# dioxido de azufre total    -0.113181        0.076470       0.035533
# densidad                    0.668047        0.022026       0.364947
# pH                         -0.682978        0.234937      -0.541904
# sulfatos                    0.183006       -0.260987       0.312770
# alcohol                    -0.061668       -0.202288       0.109903
# calidad                     0.124052       -0.390558       0.226373
#
#                          azucar residual  Cloruros  dioxido de azufre libre  \
# ...

# %%
vino1 = vino_train.drop('calidad', axis = 1)

# %%
import matplotlib.pyplot as plt

from pandas.plotting import scatter_matrix
attributes = ['acidez volátil', 'calidad', 'alcohol']
scatter_matrix(vino[attributes], figsize=(10,9))

plt.show()

# %%
attributes = ['acidez volátil', 'calidad']
scatter_matrix(vino[attributes], figsize=(10,9))

plt.show()

# %% [markdown]
# #grafique los datos con los que mayor correlacion tenian, pero quisiera ver mas(duda)

# %% [markdown]
# #Eliminar de ser necesario atributos que no sean de mucha utilidad. vamos viendo, el dato que tiene la mayor correlacion con los datos de calidad es la cantidad de alcohol......
# #

# %% [markdown]
# #Dividir en entrenmiento y testeo
# #ya esta echo la listo de entrenamiento

# %%
vino_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1279 entries, 493 to 1126
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   acidez fija              1279 non-null   float64
#  1   acidez volátil           1279 non-null   float64
#  2   ácido citrico            1279 non-null   float64
#  3   azucar residual          1279 non-null   float64
#  4   Cloruros                 1279 non-null   float64
#  5   dioxido de azufre libre  1279 non-null   float64
#  6   dioxido de azufre total  1279 non-null   float64
#  7   densidad                 1279 non-null   float64
#  8   pH                       1279 non-null   float64
#  9   sulfatos                 1279 non-null   float64
#  10  alcohol                  1279 non-null   float64
#  11  calidad                  1279 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 129.9 KB

# %%
vino.describe()
# Out:
#        acidez fija  acidez volátil  ácido citrico  azucar residual  \
# count  1599.000000     1599.000000    1599.000000      1599.000000
# mean      8.319637        0.527821       0.270976         2.538806
# std       1.741096        0.179060       0.194801         1.409928
# min       4.600000        0.120000       0.000000         0.900000
# 25%       7.100000        0.390000       0.090000         1.900000
# 50%       7.900000        0.520000       0.260000         2.200000
# 75%       9.200000        0.640000       0.420000         2.600000
# max      15.900000        1.580000       1.000000        15.500000
#
#           Cloruros  dioxido de azufre libre  dioxido de azufre total  \
# count  1599.000000              1599.000000              1599.000000
# mean      0.087467                15.874922                46.467792
# std       0.047065                10.460157                32.895324
# min       0.012000                 1.000000                 6.000000
# ...

# %% [markdown]
# De esta observación se infiere que es bueno escalar los datos.

# %% [markdown]
# #Preparar los datos para los algoritmos de Machine Learning
# Es hora de preparar los datos para sus algoritmos de Machine Learning. *listo*
#
# En lugar de hacer esto manualmente, debe escribir funciones para este propósito, por varias buenas razones: *vamos a hacer funciones*
#
# Esto le permitirá reproducir estas transformaciones fácilmente en cualquier conjunto de datos (por ejemplo, la próxima vez que obtenga un conjunto de datos nuevo).*con estas funciones podemos aplicarlas con cualquier conjunto de datos que ya esten limpios*
#
# Gradualmente construirá una biblioteca de funciones de transformación que puede reutilizar en futuros proyectos.*se hace una bilbioteca*
#
# Puede usar estas funciones en su sistema en vivo para transformar el nuevo datos antes de alimentarlos a sus algoritmos.** **listo**
#
# Esto le permitirá probar fácilmente varias transformaciones y ver qué combinación de transformaciones funciona mejor.**ver cual transformacion de datos funciona mejor**
#
# Pero primero volvamos a un conjunto de entrenamiento limpio (copiando strat_train_set una vez más).**ya esta echo**
#
# También separemos los predictores y las etiquetas, ya que no necesariamente queremos aplicar las mismas transformaciones a los predictores y los valores objetivo (tenga en cuenta que drop() crea una copia de los datos y no afecta a train_set):

# %% [markdown]
# #Separar los datos de entrenamiento en atributos X y etiquetas Y
# Esto lo haremos porque las transformaciones a los datos no se las realizaremos a la variable objetivo.

# %% [markdown]
# #imputacion de datos faltantes con Sklearn
# (Duda hace falta?)

# %% [markdown]
# Manipulación de datos categóricos
# No hay una manipulacion de datos categoricos, no hay categorias en este data sets

# %% [markdown]
# ## Escalamiento de atributos
# Una de las transformaciones más importantes que debe aplicar a sus datos es el escalado de atributos.**importante**
#
# Con pocas excepciones, los algoritmos de Machine Learning no funcionan bien cuando los atributos numéricos de entrada tienen escalas muy diferentes.**no creo que afecte tanto, en calidad**
#
# Este es el caso de los datos de vivienda: el número total de habitaciones oscila entre unas 6 y 39.320, mientras que los ingresos medios solo oscilan entre 0 y 15.
#
# Tenga en cuenta que, por lo general, no es necesario escalar los valores objetivo.
#
# Hay dos formas comunes de hacer que todos los atributos tengan la misma escala:
#
# escala minmax y
# estandarización.
# El escalado mínimo-máximo (muchas personas llaman a esto normalización) es el más simple: los valores se desplazan y se vuelven a escalar para que terminen variando de 0 a 1.
#
# Hacemos esto restando el valor mínimo y dividiendo por el máximo menos el mínimo.
#
# Scikit-Learn proporciona un transformador llamado MinMaxScaler para esto.
#
# Tiene un hiperparámetro feature_range que le permite cambiar el rango si, por alguna razón, no desea 0–1.
#
# La estandarización es diferente:
# primero resta el valor medio (por lo que los valores estandarizados siempre tienen una media cero) y luego divide por la desviación estándar para que la distribución resultante tenga varianza unitaria.
#
# A diferencia del escalado mínimo-máximo, la estandarización no vincula los valores a un rango específico, lo que puede ser un problema para algunos algoritmos (por ejemplo, las redes neuronales a menudo esperan un valor de entrada de 0 a 1).
#
# Sin embargo, la estandarización se ve mucho menos afectada por valores atípicos
#
# Por ejemplo, suponga que un distrito tiene un ingreso medio igual a 100 (por error). La escala min-max aplastaría todos los demás valores de 0 a 15 hasta 0 a 0,15, mientras que la estandarización no se vería muy afectada.

# %% [markdown]
# # Preprocesamiento y selección del modelo

# %% [markdown]
# ## Importar las librerías

# %%
import numpy as np
import pandas as pd 


from sklearn.model_selection import train_test_split 
from sklearn.preprocessing import StandardScaler


from sklearn.linear_model import LinearRegression 
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# %% [markdown]
# # Obtención de los datos

# %%
vino = pd.read_csv('vino.csv')

# %% [markdown]
# # Renombrar los nombres de las variables

# %%
vino.rename(columns = {'fixed acidity':'acidez fija','volatile acidity':'acidez volátil',\
                       'citric acid':'ácido citrico',\
                       'residual sugar':'azucar residual','chlorides':'Cloruros',\
                       'free sulfur dioxide':'dioxido de azufre libre',\
                       'total sulfur dioxide':'dioxido de azufre total',\
                       'density':'densidad','pH':'pH',\
                       'sulphates':'sulfatos','alcohol':'alcohol','quality':'calidad'},\
            inplace = True)

# %%
vino_predictores_correlaciones = vino.drop(['ácido citrico', 'azucar residual', 'dioxido de azufre libre', \
                              'densidad', 'pH'], axis = 1)

# %%
vino_predictores_correlaciones.corr().calidad
# Out:
# acidez fija                0.124052
# acidez volátil            -0.390558
# Cloruros                  -0.128907
# dioxido de azufre total   -0.185100
# sulfatos                   0.251397
# alcohol                    0.476166
# calidad                    1.000000
# Name: calidad, dtype: float64

# %% [markdown]
# # Poner solo las varibales con mejor correlación
#
# Dejar: Acides fija, acidez volatil, cloruros, dioxido de azufre total, sulfatos, alcohol
#
# Quitar: ácido citrico, azucar residual, dioxido de azufre libre, densidad y pH

# %% [markdown]
# # Dividimos en predictores X, objetivo y

# %%
vino_predictores = vino.drop(['calidad', 'ácido citrico', 'azucar residual', 'dioxido de azufre libre', \
                              'densidad', 'pH'], axis = 1)

# %%
vino_labels = vino.calidad.values

# %%
vino_labels
# Out:
# array([5, 5, 5, ..., 6, 5, 6], dtype=int64)

# %% [markdown]
# # Dividir en entrenamientyo y testeo

# %%
from sklearn.model_selection import train_test_split

vino_predictores_train, vino_predictores_test, vino_labels_train, vino_labels_test = train_test_split(vino_predictores, vino_labels, \
                                         test_size = 0.2, random_state = 42) 
#vamos bien, vamos bien

# %% [markdown]
# # Escalar los datos

# %%
escalador = StandardScaler()

# %%
X_predictores_train_escalado = escalador.fit_transform(vino_predictores_train)

# %%
vino_predictores_train = pd.DataFrame(X_predictores_train, \
                                                columns = vino_predictores_train.columns, \
                                               index = vino_predictores_train.index)

# %%
vino_predictores_train.head()
# Out:
#      acidez fija  acidez volátil  Cloruros  dioxido de azufre total  sulfatos  \
# 493     0.218332        0.889712 -0.049642                 1.042934  0.458223
# 354    -1.290166       -1.788783 -0.455214                 3.593870 -0.401197
# 342     1.494753       -0.784347  0.599272                -0.991742  0.515517
# 834     0.276351        0.861811 -0.009085                -0.718427 -1.088733
# 705     0.044274        2.814880 -0.313264                 0.222990 -0.974144
#
#       alcohol
# 493  1.123177
# 354  1.408272
# 342 -0.587390
# 834 -0.967516
# 705 -0.492358

# %%
vino_predictores_train = pd.DataFrame(X_predictores_train_escalado, \
                                                columns = vino_predictores_train.columns, \
                                               index = vino_predictores_train.index)
vino_predictores_train.head()
# Out:
#      acidez fija  acidez volátil  Cloruros  dioxido de azufre total  sulfatos  \
# 493     0.218332        0.889712 -0.049642                 1.042934  0.458223
# 354    -1.290166       -1.788783 -0.455214                 3.593870 -0.401197
# 342     1.494753       -0.784347  0.599272                -0.991742  0.515517
# 834     0.276351        0.861811 -0.009085                -0.718427 -1.088733
# 705     0.044274        2.814880 -0.313264                 0.222990 -0.974144
#
#       alcohol
# 493  1.123177
# 354  1.408272
# 342 -0.587390
# 834 -0.967516
# 705 -0.492358

# %%
vino_predictores_train_escalados.describe()

# %%
vino_predictores_train_escalados.head()

# %% [markdown]
# # Modelo LinearRegression

# %%
regresor_lineal = LinearRegression()

# %%
regresor_lineal.fit(X_predictores_train_escalado, vino_labels_train)
# Out:
# LinearRegression()

# %%
#medimos el desempeño en el de entrenamiento
primeros_cinco_vinos = X_predictores_train_escalado[:5,:]

# %%
regresor_lineal.predict(primeros_cinco_vinos) #aqui cogemos
#los valores de los cinco vinos para ver como los esta determinando respecto
#al regresor lineal
# Out:
# array([5.79609798, 6.00705855, 5.76240786, 5.09094641, 4.83689823])

# %%
#comparemos con los reales
vino_labels_train[:5]
# Out:
# array([6, 6, 6, 5, 5], dtype=int64)

# %% [markdown]
# # Ya con la asosoria se deberia de terminar arreglar el codigo

# %%
#podemos estimar su rendimiento en todos los datos de entrenamiento

# %%
calidad_predichos_train_regresion_lineal = regresor_lineal.predict(X_predictores_train_escalado)

# %%
#hallar la raiz del error cuadratico promedio
from sklearn.metrics import mean_squared_error

# %%
vino_labels_train
# Out:
# array([6, 6, 6, ..., 5, 7, 6], dtype=int64)

# %%
calidad_predichos_train_regresion_lineal
# Out:
# array([5.79609798, 6.00705855, 5.76240786, ..., 5.0739459 , 6.61379845,
#        6.69373884])

# %%
np.sqrt( mean_squared_error(vino_labels_train,calidad_predichos_train_regresion_lineal))
# Out:
# 0.6544097667401826

# %%
#dependiendo del resultado podemos pensar en usar otro tipo de regresor

# %% [markdown]
# # Usemos el regresor de arbol

# %%
regresor_tree = DecisionTreeRegressor()
regresor_tree.fit(X_predictores_train_escalado, vino_labels_train)
calidad_predichos_train_regresion_tree = regresor_tree.predict(X_predictores_train_escalado)
#calcular el error cuadratico promedio
np.sqrt( mean_squared_error(vino_labels_train,calidad_predichos_train_regresion_tree))
# Out:
# 0.0

# %%
# si nos da 0 puede que con datos nuevos no funcione bien, overfettin (sobre ajuste)

#vamos hacer una validacion cruzada

# %%
from sklearn.model_selection import cross_val_score

# %%
#hallar puntajes de desempello
puntajes = cross_val_score(regresor_tree, X_predictores_train_escalado, vino_labels_train, cv = 10,\
                           scoring = 'neg_mean_squared_error' )

# %%
np.sqrt(-puntajes).mean() #error cuadrado, puede que se halla sobre entrenado,
# Out:
# 0.7607345139658954

# %%
#metodologia de validacion cruzada
puntajes_lineal_tree = cross_val_score(calidad_predichos_train_regresion_lineal, calidad_predichos_train_regresion_tree, cv =10, \
                           scoring = 'neg_mean_squared_error' )
#muy posible que el regresor del arbol tenga una mejor eficiencia
np.sqrt(-puntajes_lineal_tree) #mostrar datos de validacion cruzada con arbol

# %% [markdown]
# # Ahora probemos RandomForest

# %%
#bosque aleatorio
regresor_forest = RandomForestRegressor()

# %%
regresor_forest.fit(X_predictores_train_escalado, vino_labels_train) 
#articulacaion de arboles de descision, se puede demorar
# Out:
# RandomForestRegressor()

# %%
#hallar puntajes de desempello
puntajes_forest = cross_val_score(regresor_forest, X_predictores_train_escalado, vino_labels_train,\
                                  cv =10, \
                           scoring = 'neg_mean_squared_error' )
np.sqrt(-puntajes_forest).mean() 
# sub dividir en 10 sub conjuntos, entrenar los complementes y 
#validar los subconjuntos, calcular el promedio
#duda no afecta que el data sets sea pequeño, todos esos sub conjuntos
# duda presentar los valores predichis con los reales
# Out:
# 0.5868591744563789

# %% [markdown]
# # Afinar el modelo

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = [
{'n_estimators':[3, 10, 30,100, 150], 'max_features':['auto', 'sqrt', 'log2', 1,10,100, 0.1,0.01,0.001],\
'max_depth':[None, 1,3,5,7]},\
{'bootstrap': [False], 'n_estimators': [3, 10], 'max_features': [2, 3, 4]}
    #2*3 son 6 modelos, (duda)
]


grid_search = GridSearchCV(regresor_forest, param_grid, cv=5,
scoring='neg_mean_squared_error',
return_train_score=True)

grid_search.fit(X_predictores_train_escalado, vino_labels_train)
# Out:
# C:\Users\Marco\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:615: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Marco\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 598, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Marco\anaconda3\lib\site-packages\sklearn\ensemble\_forest.py", line 387, in fit
#     trees = Parallel(n_jobs=self.n_jobs, verbose=self.verbose,
#   File "C:\Users\Marco\anaconda3\lib\site-packages\joblib\parallel.py", line 1043, in __call__
#     if self.dispatch_one_batch(iterator):
#   File "C:\Users\Marco\anaconda3\lib\site-packages\joblib\parallel.py", line 861, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\Marco\anaconda3\lib\site-packages\joblib\parallel.py", line 779, in _dispatch
# ...

# %%
regresor_forest_afinado = grid_search.best_estimator_

# %%
puntajes_forest_mejorado = cross_val_score(regresor_forest_afinado, \
                                           X_predictores_train, vino_labels_train, cv =10, \
                           scoring = 'neg_mean_squared_error' )
np.sqrt(-puntajes_forest_mejorado).mean()
#estariamos revizando el codigo
#variar las convinaciones para ver cuando se tiene mejor desempeño
# Out:
# 0.5855242252740739

# %% [markdown]
# # Presetar el desempeño sobre los datos a testear

# %%
#uno de testeo preparado, que coja el transformador total
X_test_preparados = escalador.transform(vino_predictores_test)

# %%
vino_labels_test_pred = regresor_forest_afinado.predict(X_test_preparados)

# %%
np.sqrt(mean_squared_error(vino_labels_test,vino_labels_test_pred ))
# Out:
# 0.5573711859155341

# %%
X_test_escalado = escalador.transform(vino_predictores_test)
primeros_cinco_vinos = X_test_escalado[:10,:]
regresor_forest_afinado.predict(primeros_cinco_vinos)
# Out:
# array([5.24      , 5.1       , 5.32666667, 5.28666667, 5.98666667,
#        5.07333333, 5.04      , 5.02      , 6.36666667, 5.89333333])

# %%
vino_labels_test[:10]
# Out:
# array([6, 5, 6, 5, 6, 5, 5, 5, 5, 6], dtype=int64)
