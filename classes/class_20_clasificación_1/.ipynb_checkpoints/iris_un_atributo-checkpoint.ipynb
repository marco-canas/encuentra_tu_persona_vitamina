# %% [markdown]
# # Cómo se clasifica cuando la regresión es logística

# %% [markdown]
# $$ y =  $$

# %% [markdown]
# # Ejemplo de clasificación de floares de iris con un atributo

# %%
import numpy as np 
import matplotlib.pyplot as plt 
from sklearn import datasets

# %%
iris = datasets.load_iris()

# %%
X = iris['data'][:,3:]

# %%
y = (iris.target == 2).astype(np.int32)

# %%
from sklearn.linear_model import LogisticRegression

# %%
log_reg = LogisticRegression()

# %%
log_reg.fit(X,y)
# Out:
# LogisticRegression()

# %%
X_new = np.linspace(0,3,1000).reshape(-1,1)

# %%
y_proba = log_reg.predict_proba(X_new)

# %%
y_proba[:5]
# Out:
# array([[9.99250016e-01, 7.49984089e-04],
#        [9.99240201e-01, 7.59799387e-04],
#        [9.99230257e-01, 7.69743043e-04],
#        [9.99220183e-01, 7.79816732e-04],
#        [9.99209978e-01, 7.90022153e-04]])

# %%
fig,ax = plt.subplots() 

ax.plot(X[y==0], y[y==0], 'bs')
ax.plot(X[y==1], y[y==1], 'g^')
ax.plot(X_new, y_proba[:,1], label = 'Iris virgínica' )
ax.plot(X_new, y_proba[:,0], label = 'No Iris virgínica' )

plt.show()

# %%
desicion_boundary = X_new[y_proba[:,1] >= 0.5][0]
desicion_boundary
# Out:
# array([1.66066066])

# %% [markdown]
# # Ahora el modelo con dos tributos

# %%
import numpy as np 
import matplotlib.pyplot as plt 
from sklearn import datasets

iris = datasets.load_iris() 

X = iris['data'][:,(2,3)] 
y = (iris.target == 2).astype(np.int32)  

from sklearn.linear_model import LogisticRegression  

log_reg = LogisticRegression() 

log_reg.fit(X,y) 

X_new = np.linspace(0,3,1000).reshape(-1,1) 

y_proba = log_reg.predict_proba(X_new)

# %%
from sklearn.linear_model import LogisticRegression

X = iris["data"][:, (2, 3)]  # petal length, petal width
y = (iris["target"] == 2).astype(np.int32)

log_reg = LogisticRegression(solver="liblinear", C=10**10, random_state=42)
log_reg.fit(X, y)

x0, x1 = np.meshgrid(
        np.linspace(2.9, 7, 500).reshape(-1, 1),
        np.linspace(0.8, 2.7, 200).reshape(-1, 1),
    )
X_new = np.c_[x0.ravel(), x1.ravel()]

y_proba = log_reg.predict_proba(X_new)

plt.figure(figsize=(10, 4))
plt.plot(X[y==0, 0], X[y==0, 1], "bs")
plt.plot(X[y==1, 0], X[y==1, 1], "g^")

zz = y_proba[:, 1].reshape(x0.shape)
contour = plt.contour(x0, x1, zz, cmap=plt.cm.brg)


left_right = np.array([2.9, 7])
boundary = -(log_reg.coef_[0][0] * left_right + log_reg.intercept_[0]) / log_reg.coef_[0][1]

plt.clabel(contour, inline=1, fontsize=12)
plt.plot(left_right, boundary, "k--", linewidth=3)
plt.text(3.5, 1.5, "Not Iris-Virginica", fontsize=14, color="b", ha="center")
plt.text(6.5, 2.3, "Iris-Virginica", fontsize=14, color="g", ha="center")
plt.xlabel("Petal length", fontsize=14)
plt.ylabel("Petal width", fontsize=14)
plt.axis([2.9, 7, 0.8, 2.7])
plt.savefig("logistic_regression_contour_plot.jpg")
plt.show()

# %% [markdown]
# ## Para acceder al vertor w

# %%
log_reg.coef_
# Out:
# array([[ 5.75286199, 10.44454566]])

# %%
log_reg.intercept_
# Out:
# array([-45.26057652])
