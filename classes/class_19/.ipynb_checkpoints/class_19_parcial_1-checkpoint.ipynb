# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/marco-canas/intro-Machine-Learning/blob/main/classes/class_19/class_19_parcial_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
# </table>

# %% [markdown]
# # Clase 19

# %% [markdown]
# # Parcial 1

# %% [markdown]
# Se evaluará sobre numpy, pandas y matplotlib

# %% [markdown]
# ## Punto 1 Numpy

# %% [markdown]
# ## Punto 2 Pandas

# %% [markdown]
# ## Punto 1 Matplotlib

# %% [markdown]
# Graficar en matplotlib la fución
#
# $$ f(s) = \frac{1}{1 + e^{-t}}  \nonumber $$
#
# en el dominio $[−4, 4]$, etiquetando los ejes y poniendo título.
#
# ¿Cuál es el comportamiento de $f$ cuando $s \to +\infty$?
#
# ¿Cuál es el comportamiento de $f$ cuando $s \to -\infty$?

# %% [markdown]
# # Clase sobre Pipeline

# %% [markdown]
# ## El diseño de Scikit - Learn

# %% [markdown]
# La API de Scikit-Learn está notablemente bien diseñada. Estos son los principales principios de diseño.

# %% [markdown]
# ## Consistencia
#
# Todos los objetos comparten una interfaz consistente y simple:

# %% [markdown]
# ## Estimadores
#
# Cualquier objeto que pueda estimar algunos parámetros basados en un conjunto de datos es llamado estimador (por ejemplo, un imputador es un estimador).

# %% [markdown]
# La estimación en sí es realizada por el método `fit()`, y toma solo un conjunto de datos como parámetro (o dos para el los algoritmos de aprendizaje supervisado); el segundo conjunto de datos contiene las etiquetas).

# %% [markdown]
# Cualquier otro parámetro necesario para guiar el proceso de estimación se considera un hiperparámetro (como la estrategia de un imputador) y debe configurarse como una variable de instancia (generalmente a través de un parámetro de constructor).

# %% [markdown]
# ## Transformadores

# %% [markdown]
# Algunos estimadores (como un imputador) también pueden transformar un conjunto de datos;
# estos se llaman transformadores.

# %% [markdown]
# La transformación la realiza el método `transform()` con el conjunto de datos a transformar como parámetro. Devuelve el conjunto de datos transformado.

# %% [markdown]
# Esta transformación generalmente se basa en los parámetros aprendidos, como es el caso de un imputador.

# %% [markdown]
# Todos los transformadores también tienen un método conveniente llamado `fit_transform()` que es equivalente a llamar a `fit()` y luego a `transform()` (pero a veces `fit_transform()` está optimizado y se ejecuta mucho más rápido).

# %% [markdown]
# ## predictores
#
# Finalmente, algunos estimadores, dado un conjunto de datos, son capaces de hacer predicciones; se llaman predictores.
#
# Por ejemplo, el modelo de regresión lineal del capítulo anterior era un predictor: dado el PIB per cápita de un país, predecía la satisfacción con la vida.
#
# Un predictor tiene un método `predict()` que toma un conjunto de datos de nuevas instancias y devuelve un conjunto de datos de las predicciones correspondientes.
#
# También tiene un método `score()` que mide la calidad de las predicciones, dado un conjunto de pruebas (y las etiquetas correspondientes, en el caso de algoritmos de aprendizaje supervisado).

# %% [markdown]
# ## Inspección

# %% [markdown]
# Se puede acceder directamente a todos los hiperparámetros del estimador a través de variables de instancia pública (p. ej., `imputer.strategy`), y se puede acceder a todos los parámetros aprendidos del estimador a través de variables de instancia pública con un sufijo de subrayado (p. ej., `imputer.statistics_`).

# %% [markdown]
# # Construcción del modelo de regreción lineal para predicción de precio de vivienda

# %% [markdown]
# Pasos para creación del cuaderno interactivo.
#
# 1. Plantear bien la pregunta.
#
#    * ¿Regresión o clasificación?
#    * ¿Tipo de regresión y tipo de clasificación?
#
# 2. Exploración inicial.
#    * Indicar la fuente de dónde se toman los datos.
#    * Hacer explícita la función objetivo.
#    * Decir cuáles son los atributos (descripción breve de cada uno)
#    * Practicar una primera síntesis tabular y una exploración gráfica de los datos.

# %% [markdown]
# 3. Preparar los datos para los algoritmos de aprendizaje.
#
#    * Hacer separación inicial de datos para entrenar y para testear.
#    * Explorar correlaciones lineales con la variable objetivo.
#    * adicionar atributos que estén mejor correlacionados con la variable objetivo.
#    * Llenar datos faltantes.
#    * Codificar las variables categóricas.
#    * Estandarizar los datos.

# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 

v = pd.read_csv('vivienda.csv')

# %% [markdown]
# # Sintesis tabular del dataset

# %%
v.info()

# %%
v.proximidad.value_counts()

# %%
v.describe()

# %% [markdown]
# # Visualizaciones

# %%
v.hist(figsize = (15,10)) 
plt.show()

# %%
v.plot(kind = 'scatter', x = 'longitud', y = 'latitud', alpha = 1, figsize = (10,6)) 
plt.show()

# %%
import matplotlib.pyplot as plt 

v.plot(kind = 'scatter', x = 'longitud', y = 'latitud', alpha = 0.4, figsize = (12,8),\
      s = v.población/100, label = 'Población', \
      c = 'valor', cmap = plt.get_cmap('jet'), colorbar = True)  
plt.show()

# %% [markdown]
# # Buscando correlaciones

# %% [markdown]
# Dado que el conjunto de datos no es demasiado grande, puede calcular fácilmente el coeficiente de correlación estándar (también llamado r de Pearson) entre cada par de atributos usando el método `corr()`:

# %%
v.corr()

# %% [markdown]
# Ahora veamos cómo cada atributo está correlacionado con la variable objetivo de precio promedio de vivienda por distrito:

# %%
v.corr().precio.sort_values(ascending = False)
# Out:
# precio          1.000000
# ingresos        0.688075
# habitaciones    0.134153
# antiguedad      0.105623
# hogares         0.065843
# dormitorios     0.049686
# población      -0.024650
# longitud       -0.045967
# latitud        -0.144160
# Name: precio, dtype: float64

# %% [markdown]
# El coeficiente de correlación varía de –1 a 1.

# %% [markdown]
# Cuando es cercano a 1, significa que existe una fuerte correlación positiva; por ejemplo, el valor medio de la vivienda tiende a aumentar cuando aumenta el ingreso medio.

# %% [markdown]
# Cuando el coeficiente es cercano a –1, significa que existe una fuerte correlación negativa; puede ver una pequeña correlación negativa entre la latitud y el precio medio de la vivienda (es decir, los precios tienen una ligera tendencia a bajar cuando va hacia el norte).

# %% [markdown]
# Finalmente, los coeficientes cercanos a 0 significan que no existe una correlación lineal.

# %% [markdown]
# La siguiente figura muestra varios gráficos junto con el coeficiente de correlación entre sus ejes horizontal y vertical.

# %% [markdown]
# <img src = 'https://github.com/marco-canas/intro-Machine-Learning/blob/main/classes/class_17_/coeficientes_de_correlaci%C3%B3n_est%C3%A1ndar.png?raw=true'>

# %%
import matplotlib.pyplot as plt 

from pandas.plotting import scatter_matrix
attributes = ['precio', 'ingresos', 'latitud'] 
scatter_matrix(v[attributes], figsize=(9, 5))

plt.show()

# %%
v.plot(kind="scatter", x='ingresos', y='precio', alpha=0.1, figsize = (9,5))

plt.show()

# %% [markdown]
# Esta gráfico revela algunas cosas.
#
# * Primero, la correlación es de hecho muy fuerte; se puede ver claramente la tendencia al alza, y los puntos no están demasiado dispersos.
#
# * En segundo lugar, el límite de precio que notamos anteriormente es claramente visible como una línea horizontal en $500,000.

# %% [markdown]
# Pero este gráfico revela otras líneas rectas menos obvias:
#
# * una línea horizontal alrededor de $450 000,
#
# * otra alrededor de $350 000,
#
# * quizás una alrededor de $280 000 y algunas más por debajo de esa.
#
# Es posible que desee intentar eliminar los distritos correspondientes para evitar que sus algoritmos aprendan a reproducir estas peculiaridades de los datos.

# %% [markdown]
# ## Experimentando con combinaciones de atributos

# %% [markdown]
# Identificó algunas peculiaridades de los datos que quizás desee limpiar antes de enviar los datos a un algoritmo de aprendizaje automático y encontró correlaciones interesantes entre los atributos, en particular con el atributo objetivo.

# %% [markdown]
# Una última cosa que quizás desee hacer antes de preparar los datos para los algoritmos de Machine Learning es probar varias combinaciones de atributos.
#
# Por ejemplo, el número total de habitaciones en un distrito no es muy útil si no sabe cuántos hogares hay.
#
# Lo que realmente desea es el número de **habitaciones por hogar**.

# %% [markdown]
# Del mismo modo, el número total de **dormitorios** por sí solo no es muy útil: probablemente quieras compararlo con el número de **habitaciones**.
#
# Y la **población por hogar** también parece una combinación de atributos interesante para observar.
#
# Vamos a crear estos nuevos atributos:

# %%
v['habitaciones_por_hogar'] = v.habitaciones/v.hogares 
v['dormitorios_por_habitación'] = v.dormitorios/v.habitaciones 
v['población_por_hogar'] = v.población/v.hogares
